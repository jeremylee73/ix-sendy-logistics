# %%
import pandas as pd
import seaborn as sns
import missingno as msno

# %%
riders = pd.read_csv("data/Riders.csv")
riders.head()
# Out:
#        Rider Id  No_Of_Orders   Age  Average_Rating  No_of_Ratings
# 0  Rider_Id_396          2946  2298            14.0           1159
# 1  Rider_Id_479           360   951            13.5            176
# 2  Rider_Id_648          1746   821            14.3            466
# 3  Rider_Id_753           314   980            12.5             75
# 4  Rider_Id_335           536  1113            13.7            156

# %%
sample = pd.read_csv("data/SampleSubmission.csv")
sample.head()
# Out:
#          Order_No  Time from Pickup to Arrival
# 0  Order_No_19248                        567.0
# 1  Order_No_12736                       4903.0
# 2    Order_No_768                       5649.0
# 3  Order_No_15332                          NaN
# 4  Order_No_21373                          NaN

# %%
print("testing")
# Out:
# testing

# %%
sample.shape
# Out:
# (7068, 2)

# %%
sample.dtypes
# Out:
# Order_No                        object
# Time from Pickup to Arrival    float64
# dtype: object

# %%
sample = sample.rename({"Order_No": "order_number", "Time from Pickup to Arrival": "pickup_to_arrival_time"}, axis='columns')

# %%
for i in range(7068):
    raw = sample["order_number"][i]
    shortened = raw[9:]
    sample["order_number"][i] = shortened
# Out:
# <ipython-input-65-a3225d03f051>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sample["order_number"][i] = shortened

# %%
sample.head()
# Out:
#   order_number  pickup_to_arrival_time
# 0        19248                   567.0
# 1        12736                  4903.0
# 2          768                  5649.0
# 3        15332                     NaN
# 4        21373                     NaN

# %%
sample.astype({'order_number': 'int64'})
# Out:
#       order_number  pickup_to_arrival_time
# 0            19248                   567.0
# 1            12736                  4903.0
# 2              768                  5649.0
# 3            15332                     NaN
# 4            21373                     NaN
# ...            ...                     ...
# 7063          3612                     NaN
# 7064          7657                     NaN
# 7065          1969                     NaN
# 7066         10591                     NaN
# 7067          1603                     NaN
#
# [7068 rows x 2 columns]

# %%
test = pd.read_csv("data/Test.csv")
test.head()
# Out:
#          Order No       User Id Vehicle Type  Platform Type  \
# 0  Order_No_19248  User_Id_3355         Bike              3
# 1  Order_No_12736  User_Id_3647         Bike              3
# 2    Order_No_768  User_Id_2154         Bike              3
# 3  Order_No_15332  User_Id_2910         Bike              3
# 4  Order_No_21373  User_Id_1205         Bike              3
#
#   Personal or Business  Placement - Day of Month  \
# 0             Business                        27
# 1             Business                        17
# 2             Business                        27
# 3             Business                        17
# 4             Business                        11
#
#    Placement - Weekday (Mo = 1) Placement - Time  Confirmation - Day of Month  \
# 0                             3       4:44:10 PM                           27
# 1                             5      12:57:35 PM                           17
# ...

# %%
train = pd.read_csv("data/Train.csv")
train.head()
# Out:
#          Order No       User Id Vehicle Type  Platform Type  \
# 0   Order_No_4211   User_Id_633         Bike              3
# 1  Order_No_25375  User_Id_2285         Bike              3
# 2   Order_No_1899   User_Id_265         Bike              3
# 3   Order_No_9336  User_Id_1402         Bike              3
# 4  Order_No_27883  User_Id_1737         Bike              1
#
#   Personal or Business  Placement - Day of Month  \
# 0             Business                         9
# 1             Personal                        12
# 2             Business                        30
# 3             Business                        15
# 4             Personal                        13
#
#    Placement - Weekday (Mo = 1) Placement - Time  Confirmation - Day of Month  \
# 0                             5       9:35:46 AM                            9
# 1                             5      11:16:16 AM                           12
# ...

# %%
variable = pd.read_csv("data/VariableDefinitions.csv")
variable.head()
# Out:
#                    Order No                Unique number identifying the order
# 0                   User Id  Unique number identifying the customer on a pl...
# 1              Vehicle Type  For this competition limited to bikes, however...
# 2             Platform Type  Platform used to place the order, there are 4 ...
# 3      Personal or Business                                      Customer type
# 4  Placement - Day of Month                  Placement - Day of Month i.e 1-31
